# %% [markdown]
# # Avaliação e Refinamento do Modelo.

# %%
# Instalar bibliotecas.
#%pip install pandas matplotlib scipy scikit-learn seaborn ipywidgets

# %% [markdown]
# Este conjunto de dados foi hospedado no objeto IBM Cloud. Clique <a href="https://cocl.us/DA101EN_object_storage">AQUI</a> para armazenamento gratuito.

# %%
import pandas as pd
import numpy as np
from ipywidgets import interact, interactive, fixed, interact_manual
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
# Importanto os dados limpos.
path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/module_5_auto.csv'
df = pd.read_csv(path)

# %% [markdown]
# #### Dropando colunas e traduzindo.

# %%
df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1, inplace=True)
termos_traduzidos = [
    'classificação', 'perdas-normalizadas', 'fabricante', 'aspiraçao', 'num-de-portas',
    'estilo-de-carro', 'tracao', 'localizacao-do-motor', 'distancia-entre-eixos', 'comprimento',
    'largura', 'altura', 'peso-do-meio-fio', 'tipo-de-motor', 'num-de-cilindros',
    'tamanho-do-motor', 'sistema-de-combustível', 'diametro-do-cilindro', 'curso-do-pistao', 'taxa-de-compressao',
    'potencia', 'rpm-pico', 'consumo-na-cidade', 'consumo-na-estrada', 'preco',
    'consumo-na-cidade-L/100km', 'potencia-categorizada', 'diesel', 'gasolina'
]
df.columns = termos_traduzidos
df.head()
# Out:
#    classificação  perdas-normalizadas   fabricante aspiraçao num-de-portas  \
# 0              3                  122  alfa-romero       std           two
# 1              3                  122  alfa-romero       std           two
# 2              1                  122  alfa-romero       std           two
# 3              2                  164         audi       std          four
# 4              2                  164         audi       std          four
#
#   estilo-de-carro tracao localizacao-do-motor  distancia-entre-eixos  \
# 0     convertible    rwd                front                   88.6
# 1     convertible    rwd                front                   88.6
# 2       hatchback    rwd                front                   94.5
# 3           sedan    fwd                front                   99.8
# 4           sedan    4wd                front                   99.4
#
#    comprimento  ...  taxa-de-compressao  potencia  rpm-pico consumo-na-cidade  \
# 0     0.811148  ...                 9.0     111.0    5000.0                21
# 1     0.811148  ...                 9.0     111.0    5000.0                21
# 2     0.822681  ...                 9.0     154.0    5000.0                19
# 3     0.848630  ...                10.0     102.0    5500.0                24
# 4     0.848630  ...                 8.0     115.0    5500.0                18
#
#   consumo-na-estrada    preco consumo-na-cidade-L/100km  \
# 0                 27  13495.0                 11.190476
# 1                 27  16500.0                 11.190476
# 2                 26  16500.0                 12.368421
# 3                 30  13950.0                  9.791667
# 4                 22  17450.0                 13.055556
#
#    potencia-categorizada  diesel  gasolina
# 0                 Medium       0         1
# 1                 Medium       0         1
# 2                 Medium       0         1
# 3                 Medium       0         1
# 4                 Medium       0         1
#
# [5 rows x 29 columns]

# %%
df.to_csv('carros85_clean.csv')

# %% [markdown]
# Primeiro iremos usar somente os dados numericos

# %%
df=df._get_numeric_data()
df.head()
# Out:
#    classificação  perdas-normalizadas  distancia-entre-eixos  comprimento  \
# 0              3                  122                   88.6     0.811148
# 1              3                  122                   88.6     0.811148
# 2              1                  122                   94.5     0.822681
# 3              2                  164                   99.8     0.848630
# 4              2                  164                   99.4     0.848630
#
#     largura  altura  peso-do-meio-fio  tamanho-do-motor  diametro-do-cilindro  \
# 0  0.890278    48.8              2548               130                  3.47
# 1  0.890278    48.8              2548               130                  3.47
# 2  0.909722    52.4              2823               152                  2.68
# 3  0.919444    54.3              2337               109                  3.19
# 4  0.922222    54.3              2824               136                  3.19
#
#    curso-do-pistao  taxa-de-compressao  potencia  rpm-pico  consumo-na-cidade  \
# 0             2.68                 9.0     111.0    5000.0                 21
# 1             2.68                 9.0     111.0    5000.0                 21
# 2             3.47                 9.0     154.0    5000.0                 19
# 3             3.40                10.0     102.0    5500.0                 24
# 4             3.40                 8.0     115.0    5500.0                 18
#
#    consumo-na-estrada    preco  consumo-na-cidade-L/100km  diesel  gasolina
# 0                  27  13495.0                  11.190476       0         1
# 1                  27  16500.0                  11.190476       0         1
# 2                  26  16500.0                  12.368421       0         1
# 3                  30  13950.0                   9.791667       0         1
# 4                  22  17450.0                  13.055556       0         1

# %% [markdown]
# ### Funções para gráficos.

# %%
def DistributionPlot(FuncaoVermelha, FuncaoAzul, NomeVermelho, NomeAzul, Titulo):
    largura = 12
    altura = 10
    plt.figure(figsize=(largura, altura))

    ax1 = sns.kdeplot(FuncaoVermelha, color="r", label=NomeVermelho)
    ax2 = sns.kdeplot(FuncaoAzul, color="b", label=NomeAzul, ax=ax1)

    plt.title(Titulo)
    plt.xlabel('Preco em U$')
    plt.ylabel('Proporção de Carros')
    plt.show()
    plt.close()

# %%
def PollyPlot(xtreino, xteste, y_treino, y_teste, lr,poly_transform):
    largura = 12
    altura = 10
    plt.figure(figsize=(largura, altura))
    
    
    #training data 
    #testing data 
    # lr:  linear regression object 
    #poly_transform:  polynomial transformation object 
 
    xmax=max([xtreino.values.max(), xteste.values.max()])

    xmin=min([xtreino.values.min(), xteste.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtreino, y_treino, 'ro', label='Dados de Treinamento')
    plt.plot(xteste, y_teste, 'go', label='Dados de Teste')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Função de Previsão')
    plt.ylim([-10000, 60000])
    plt.ylabel('Preço')
    plt.legend()

# %% [markdown]
# ## Treino e Teste.

# %%
# dados com o target
y_data = df['preco']

# %%
x_data=df.drop('preco',axis=1)

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

print("Numero de amostras de teste: ", x_teste.shape[0])
print("Numero de amostras de treino: ",x_treino.shape[0])
# Out:
# Numero de amostras de teste:  21
# Numero de amostras de treino:  180

# %%
# Novo conjunto de testes
x_treino1, x_teste1, y_treino1, y_teste1 = train_test_split(x_data, y_data, test_size=0.40, random_state=0)

print("Numero de amostras de teste: ", x_teste1.shape[0])
print("Numero de amostras de treino: ",x_treino1.shape[0])
# Out:
# Numero de amostras de teste:  81
# Numero de amostras de treino:  120

# %% [markdown]
# Ajustamos o modelo usando o recurso “potência”:

# %%
lre=LinearRegression()
lre.fit(x_treino[['potencia']], y_treino)
# Out:
# LinearRegression()

# %%
print('O coeficiente de determinação:', lre.score(x_teste[['potencia']], y_teste))
# Out:
# O coeficiente de determinação: 0.3635875575078824

# %%
print('O coeficiente de determinação:',lre.score(x_treino[['potencia']], y_treino))
# Out:
# O coeficiente de determinação: 0.6619724197515103

# %% [markdown]
# Podemos perceber que o coeficiente de determinação "R²", é muito menor utilizando as amostras de teste comparadas com as de treino.

# %%
lre.fit(x_treino1[['potencia']],y_treino1)
print('O coeficiente de de determinação: ', lre.score(x_teste1[['potencia']],y_teste1))
# Out:
# O coeficiente de de determinação:  0.7139364665406974

# %% [markdown]
# Para o modelo utilizando 40% do dataset o coeficiente ja sobe, ~0.71.

# %% [markdown]
# <h2>Cross-Validation Score</h2>

# %% [markdown]
# Inserimos o objeto, o recurso ("potencia") e os dados de destino (y_data). O parâmetro 'cv' determina o número de dobras. Neste caso, é 4.

# %%
Rcross = cross_val_score(lre, x_data[['potencia']], y_data, cv=4)
Rcross
# Out:
# array([0.7746232 , 0.51716687, 0.74785353, 0.04839605])

# %%
print("A média das dobras ", Rcross.mean(), "e o desvio padrão " , Rcross.std())
# Out:
# A média das dobras  0.522009915042119 e o desvio padrão  0.2911839444756029

# %% [markdown]
# Podemos usar o erro quadrático negativo como pontuação definindo a métrica do parâmetro 'pontuação' como 'neg_mean_squared_error'.

# %%
-1 * cross_val_score(lre,x_data[['potencia']], y_data,cv=4,scoring='neg_mean_squared_error')
# Out:
# array([20254142.84026704, 43745493.26505169, 12539630.34014931,
#        17561927.72247591])

# %% [markdown]
# Agora um teste usando só 2 dobras.

# %%
Rc=cross_val_score(lre,x_data[['potencia']], y_data,cv=2)
Rc.mean()
# Out:
# 0.5166761697127431

# %%
print("A média das dobras ", Rc.mean(), "e o desvio padrão " , Rc.std())
# Out:
# A média das dobras  0.5166761697127431 e o desvio padrão  0.07348004195771368

# %% [markdown]
# Usar a função 'cross_val_predict' para prever a saída. A função divide os dados em um número especificado de dobras, com uma dobra para teste e as outras dobras são usadas para treinamento.

# %%
yhat = cross_val_predict(lre,x_data[['potencia']], y_data,cv=4)
yhat[0:5]
# Out:
# array([14141.63807508, 14141.63807508, 20814.29423473, 12745.03562306,
#        14762.35027598])

# %% [markdown]
# ## Overfitting, Underfitting e Seleção de Modelo

# %% [markdown]
# Acontece que os dados de teste, às vezes chamados de "dados fora da amostra", são uma medida muito melhor do desempenho do seu modelo no mundo real. Uma razão para isso é o overfitting.
#
# Vejamos alguns exemplos. Acontece que essas diferenças são mais aparentes na regressão linear múltipla e na regressão polinomial, portanto exploraremos o sobreajuste nesse contexto.

# %% [markdown]
# Múltiplos objetos de regressão linear e treinar o modelo usando 'cavalo-vapor', 'peso-meio-fio', 'tamanho do motor' e 'rodovia-mpg' como recursos.

# %%
lr = LinearRegression()
lr.fit(x_treino[['potencia', 'peso-do-meio-fio', 'tamanho-do-motor', 'consumo-na-estrada']], y_treino)
# Out:
# LinearRegression()

# %% [markdown]
# Previsão usando dados de treinamento:

# %%
yhat_treino = lr.predict(x_treino[['potencia', 'peso-do-meio-fio', 'tamanho-do-motor', 'consumo-na-estrada']])
yhat_treino[0:5]
# Out:
# array([ 7426.6731551 , 28323.75090803, 14213.38819709,  4052.34146983,
#        34500.19124244])

# %% [markdown]
# Previsão usando dados de teste:

# %%
yhat_teste = lr.predict(x_teste[['potencia', 'peso-do-meio-fio', 'tamanho-do-motor', 'consumo-na-estrada']])
yhat_teste[0:5]
# Out:
# array([11349.35089149,  5884.11059106, 11208.6928275 ,  6641.07786278,
#        15565.79920282])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
Title = 'Gráfico de distribuição do valor previsto usando dados de treinamento versus distribuição de dados de treinamento'
DistributionPlot(y_treino, yhat_treino, "Valores Atuais (Treino)", "Valores Previstos (Treino)", Title)

# %% [markdown]
# Comparação com os valores reais dos dados de treinamento.

# %%
Title= 'Gráfico de distribuição do valor previsto usando dados de teste versus distribuição de dados de teste'
DistributionPlot(y_teste,yhat_teste,"Valores Atuais (Treino)", "Valores Previstos (Treino)",Title)

# %% [markdown]
# Comparando a Figura 1 e a Figura 2, é evidente que a distribuição dos dados de teste na Figura 1 é muito melhor no ajuste dos dados. Esta diferença na Figura 2 é aparente na faixa de 5.000 a 15.000. É aqui que a forma da distribuição é extremamente diferente. Vamos ver se a regressão polinomial também apresenta uma queda na precisão da previsão ao analisar o conjunto de dados de teste.

# %% [markdown]
# <h4> Overfitting </h4>
# <p>O overfitting ocorre quando o modelo se ajusta ao ruído, mas não ao processo subjacente. Portanto, ao testar seu modelo usando o conjunto de testes, seu modelo não tem um desempenho tão bom, pois está modelando ruído, e não o processo subjacente que gerou o relacionamento. Vamos criar um modelo polinomial de grau 5.</p>

# %%
# Vamos usar 55% dos dados para treinamento e o restante para teste:
x_treino, x_teste, y_treino, y_teste = train_test_split(x_data, y_data, test_size=0.45, random_state=0)

# %%
# Realizaremos uma transformação polinomial de grau 5 no recurso 'cavalos de potência'.
pr = PolynomialFeatures(degree=5)
x_treino_pr = pr.fit_transform(x_treino[['potencia']])
x_teste_pr = pr.fit_transform(x_teste[['potencia']])
pr
# Out:
# PolynomialFeatures(degree=5)

# %%
# Agora, vamos criar um modelo de regressão linear "poly" e treiná-lo.
poly = LinearRegression()
poly.fit(x_treino_pr, y_treino)
# Out:
# LinearRegression()

# %%
# Podemos ver o resultado do nosso modelo usando o método “predict”. Atribuímos os valores a "yhat".
yhat = poly.predict(x_teste_pr)
yhat[0:5]
# Out:
# array([ 6728.63702958,  7307.96989706, 12213.77721798, 18893.28623041,
#        19995.9928222 ])

# %%
# Vamos pegar os primeiros cinco valores previstos e compará-los com as metas reais.
print("Valores previstos: ", yhat[0:4])
print("Valores reais: ", y_teste[0:4].values)
# Out:
# Valores previstos:  [ 6728.63702958  7307.96989706 12213.77721798 18893.28623041]
# Valores reais:  [ 6295. 10698. 13860. 13499.]

# %%
PollyPlot(x_treino['potencia'], x_teste['potencia'], y_treino, y_teste, poly,pr)

# %% [markdown]
# Um modelo de regressão polinomial onde os pontos vermelhos representam os dados de treinamento, os pontos verdes representam os dados de teste e a linha azul representa a previsão do modelo.

# %% [markdown]
# Vemos que a função estimada parece rastrear os dados, mas por volta de 200 cavalos de potência, a função começa a divergir dos pontos de dados.

# %%
# R² para dados de treino
poly.score(x_treino_pr, y_treino)
# Out:
# 0.5567716901606525

# %%
# R² para dados de teste
poly.score(x_teste_pr, y_teste)
# Out:
# -29.871300058119907

# %% [markdown]
# Vemos que o R² para os dados de treinamento é 0,5567, enquanto o R² nos dados de teste foi -29,87. Quanto menor o R², pior é o modelo. Um R² negativo é um sinal de overfitting.

# %% [markdown]
# Vamos ver como o R² muda nos dados de teste para polinômios de ordem diferente e, em seguida, traçar os resultados:

# %%
Rsqu_teste = []

ordem = [1, 2, 3, 4]
for n in ordem:
    pr = PolynomialFeatures(degree=n)
    
    x_treino_pr = pr.fit_transform(x_treino[['potencia']])
    
    x_teste_pr = pr.fit_transform(x_teste[['potencia']])    
    
    lr.fit(x_treino_pr, y_treino)
    
    Rsqu_teste.append(lr.score(x_teste_pr, y_teste))

plt.plot(ordem, Rsqu_teste)
plt.xlabel('ordem')
plt.ylabel('R²')
plt.title('R² usando dados de teste')
plt.text(3, 0.75, 'R² máximo ')
# Out:
# Text(3, 0.75, 'R² máximo ')

# %% [markdown]
# Vemos que R² aumenta gradualmente até que um polinômio de ordem três seja usado. Então, o R² diminui drasticamente em um polinômio de ordem quatro.

# %%
def f(ordem, teste_data):
    x_treino, x_teste, y_treino, y_teste = train_test_split(x_data, y_data, test_size=teste_data, random_state=0)
    pr = PolynomialFeatures(degree=ordem)
    x_treino_pr = pr.fit_transform(x_treino[['potencia']])
    x_teste_pr = pr.fit_transform(x_teste[['potencia']])
    poly = LinearRegression()
    poly.fit(x_treino_pr,y_treino)
    PollyPlot(x_treino['potencia'], x_teste['potencia'], y_treino,y_teste, poly, pr)

# %%
interact(f, ordem=(0, 6, 1), teste_data=(0.05, 0.95, 0.05))
# Out:
# interactive(children=(IntSlider(value=3, description='ordem', max=6), FloatSlider(value=0.45, description='tes…
# <function __main__.f(ordem, teste_data)>

# %% [markdown]
# Agora iremos fazer uma analise para um polinomio de grau 2, e as amostras de treinamento e teste para os recursos 'potencia', 'peso-do-meio-fio', 'tamanho-do-motor', 'consumo-na-estrada'.

# %%
pr1 = PolynomialFeatures(degree=2)

# %%
x_treino_pr1=pr1.fit_transform(x_treino[[ 'potencia', 'peso-do-meio-fio', 'tamanho-do-motor', 'consumo-na-estrada']])

x_teste_pr1=pr1.fit_transform(x_teste[['potencia', 'peso-do-meio-fio', 'tamanho-do-motor', 'consumo-na-estrada']])

# %%
x_treino_pr1.shape
# Out:
# (110, 15)

# %%
poly1=LinearRegression().fit(x_treino_pr1,y_treino)

# %%
yhat_teste1=poly1.predict(x_teste_pr1)

Title='Gráfico de distribuição do valor previsto usando dados de teste versus distribuição de dados de teste'

DistributionPlot(y_teste, yhat_teste1, "Valores Atuais Teste", "Valores Previstos Teste", Title)

# %% [markdown]
# O valore previsto é superior ao valor real para carros cujo preço varia de $10.000, inversamente, o preço previsto é inferior ao preço de custo na faixa de $30.000 e $40.000. Como tal, o modelo não é tão preciso nestas faixas.

# %% [markdown]
# ## Regressão de Ridge

# %% [markdown]
# Nesta seção, revisaremos a regressão de Ridge e veremos como o parâmetro alfa altera o modelo. Apenas uma observação: aqui nossos dados de teste serão usados ​​como dados de validação.
#
# Vamos realizar uma transformação polinomial de grau dois em nossos dados.

# %%
pr=PolynomialFeatures(degree=2)
x_train_pr=pr.fit_transform(x_treino[['potencia', 'peso-do-meio-fio', 'tamanho-do-motor', 'consumo-na-estrada','perdas-normalizadas','classificação']])
x_test_pr=pr.fit_transform(x_teste[['potencia', 'peso-do-meio-fio', 'tamanho-do-motor', 'consumo-na-estrada','perdas-normalizadas','classificação']])

# %% [markdown]
# Vamos criar um objeto de regressão Ridge, definindo o parâmetro de regularização (alfa) como 1

# %%
RigeModel=Ridge(alpha=1)

# %%
RigeModel.fit(x_treino_pr, y_treino)
# Out:
# /home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.17189e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# Ridge(alpha=1)

# %%
yhat = RigeModel.predict(x_teste_pr)

# %%
print('Previsto: ', yhat[0:4])
print('Set de teste: ', y_teste[0:4].values)
# Out:
# Previsto:  [ 7439.15485492  7826.49627157 11284.32208136 19953.96351143]
# Set de teste:  [ 6295. 10698. 13860. 13499.]

# %% [markdown]
# Selecionamos o valor de alfa que minimiza o erro do teste. Para fazer isso, podemos usar um loop for. Também criamos uma barra de progresso para ver quantas iterações concluímos até agora.

# %%
from tqdm import tqdm

Rsqu_teste = []
Rsqu_treino = []
dummy1 = []
Alpha = 10 * np.array(range(0,1000))
pbar = tqdm(Alpha)

for alpha in pbar:
    RigeModel = Ridge(alpha=alpha) 
    RigeModel.fit(x_treino_pr, y_treino)
    teste_score, treino_score = RigeModel.score(x_teste_pr, y_teste), RigeModel.score(x_treino_pr, y_treino)
    
    pbar.set_postfix({"Score de teste": test_score, "Score de treino": treino_score})

    Rsqu_teste.append(teste_score)
    Rsqu_treino.append(treino_score)
# Out:
#   0%|     | 0/1000 [00:00<?, ?it/s, Score de teste=0.406, Score de treino=0.535]/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.17189e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|     | 0/1000 [00:00<?, ?it/s, Score de teste=0.406, Score de treino=0.535]/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.34378e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|     | 0/1000 [00:00<?, ?it/s, Score de teste=0.406, Score de treino=0.535]/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.51567e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|     | 0/1000 [00:00<?, ?it/s, Score de teste=0.406, Score de treino=0.534]/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=4.68756e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|     | 0/1000 [00:00<?, ?it/s, Score de teste=0.406, Score de treino=0.534]/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.85945e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|     | 0/1000 [00:00<?, ?it/s, Score de teste=0.406, Score de treino=0.534]/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.03134e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|     | 0/1000 [00:00<?, ?it/s, Score de teste=0.406, Score de treino=0.534]/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.20323e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|     | 0/1000 [00:00<?, ?it/s, Score de teste=0.406, Score de treino=0.534]/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.37512e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|     | 0/1000 [00:00<?, ?it/s, Score de teste=0.406, Score de treino=0.534]/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.0547e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|     | 0/1000 [00:00<?, ?it/s, Score de teste=0.406, Score de treino=0.534]/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.17189e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   1%| | 11/1000 [00:00<00:09, 100.53it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.28908e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   1%| | 11/1000 [00:00<00:09, 100.53it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.40627e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   1%| | 11/1000 [00:00<00:09, 100.53it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.52346e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   1%| | 11/1000 [00:00<00:09, 100.53it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.64065e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   1%| | 11/1000 [00:00<00:09, 100.53it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.75784e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   1%| | 11/1000 [00:00<00:09, 100.53it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.87502e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   1%| | 11/1000 [00:00<00:09, 100.53it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.99221e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   1%| | 11/1000 [00:00<00:09, 100.53it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.1094e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   1%| | 11/1000 [00:00<00:09, 100.53it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.22659e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   1%| | 11/1000 [00:00<00:09, 100.53it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.34378e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   1%| | 11/1000 [00:00<00:09, 100.53it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.46097e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   2%| | 22/1000 [00:00<00:09, 100.71it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.57816e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   2%| | 22/1000 [00:00<00:09, 100.71it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.69535e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   2%| | 22/1000 [00:00<00:09, 100.71it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.81254e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   2%| | 22/1000 [00:00<00:09, 100.71it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.92973e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   2%| | 22/1000 [00:00<00:09, 100.71it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.04692e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   2%| | 22/1000 [00:00<00:09, 100.71it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.1641e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   2%| | 22/1000 [00:00<00:09, 100.71it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.28129e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   2%| | 22/1000 [00:00<00:09, 100.71it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.39848e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   2%| | 22/1000 [00:00<00:09, 100.71it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.51567e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   2%| | 22/1000 [00:00<00:09, 100.71it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.63286e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   2%| | 22/1000 [00:00<00:09, 100.71it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.75005e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   3%| | 33/1000 [00:00<00:09, 101.37it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.86724e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   3%| | 33/1000 [00:00<00:09, 101.37it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.98443e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   3%| | 33/1000 [00:00<00:09, 101.37it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=4.10162e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   3%| | 33/1000 [00:00<00:09, 101.37it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=4.21881e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   3%| | 33/1000 [00:00<00:09, 101.37it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=4.33599e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   3%| | 33/1000 [00:00<00:09, 101.37it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=4.45318e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   3%| | 33/1000 [00:00<00:09, 101.37it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=4.57037e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   3%| | 33/1000 [00:00<00:09, 101.37it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=4.68756e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   3%| | 33/1000 [00:00<00:09, 101.37it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=4.80475e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   3%| | 33/1000 [00:00<00:09, 101.37it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=4.92194e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   3%| | 33/1000 [00:00<00:09, 101.37it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.03913e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.15632e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.27351e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.3907e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.50788e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.62507e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.74226e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.85945e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.97664e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.09383e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.21102e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.32821e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.4454e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.56259e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   4%| | 44/1000 [00:00<00:09, 102.75it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.67978e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   6%| | 58/1000 [00:00<00:08, 115.09it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.79696e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   6%| | 58/1000 [00:00<00:08, 115.09it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.91415e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   6%| | 58/1000 [00:00<00:08, 115.09it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.03134e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   6%| | 58/1000 [00:00<00:08, 115.09it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.14853e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   6%| | 58/1000 [00:00<00:08, 115.09it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.26572e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   6%| | 58/1000 [00:00<00:08, 115.09it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.38291e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   6%| | 58/1000 [00:00<00:08, 115.09it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.5001e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   6%| | 58/1000 [00:00<00:08, 115.09it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.61729e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   6%| | 58/1000 [00:00<00:08, 115.09it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.73448e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   6%| | 58/1000 [00:00<00:08, 115.09it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.85167e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   6%| | 58/1000 [00:00<00:08, 115.09it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.96885e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   6%| | 58/1000 [00:00<00:08, 115.09it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.08604e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   7%| | 70/1000 [00:00<00:07, 116.60it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.20323e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   7%| | 70/1000 [00:00<00:07, 116.60it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.32042e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   7%| | 70/1000 [00:00<00:07, 116.60it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.43761e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   7%| | 70/1000 [00:00<00:07, 116.60it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.5548e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   7%| | 70/1000 [00:00<00:07, 116.60it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.67199e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   7%| | 70/1000 [00:00<00:07, 116.60it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.78918e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   7%| | 70/1000 [00:00<00:07, 116.60it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.90637e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   7%| | 70/1000 [00:00<00:07, 116.60it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.02356e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   7%| | 70/1000 [00:00<00:07, 116.60it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.14075e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   7%| | 70/1000 [00:00<00:07, 116.60it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.25793e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   7%| | 70/1000 [00:00<00:07, 116.60it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.37512e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   7%| | 70/1000 [00:00<00:07, 116.60it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.49231e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   8%| | 82/1000 [00:00<00:08, 114.43it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.6095e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   8%| | 82/1000 [00:00<00:08, 114.43it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.72669e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   8%| | 82/1000 [00:00<00:08, 114.43it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.84388e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   8%| | 82/1000 [00:00<00:08, 114.43it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.96107e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   8%| | 82/1000 [00:00<00:08, 114.43it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.00783e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   8%| | 82/1000 [00:00<00:08, 114.43it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.01954e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   8%| | 82/1000 [00:00<00:08, 114.43it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.03126e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   8%| | 82/1000 [00:00<00:08, 114.43it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.04298e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   8%| | 82/1000 [00:00<00:08, 114.43it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.0547e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   8%| | 82/1000 [00:00<00:08, 114.43it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.06642e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   8%| | 82/1000 [00:00<00:08, 114.43it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.07814e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   8%| | 82/1000 [00:00<00:08, 114.43it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.08986e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   8%| | 82/1000 [00:00<00:08, 114.43it/s, Score de teste=0.406, Score de treino=/home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.10158e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# 100%|█| 1000/1000 [00:07<00:00, 128.21it/s, Score de teste=0.406, Score de trein

# %% [markdown]
# Podemos traçar o valor de R ^ 2 para diferentes alfas:

# %%
largura = 12
altura = 10
plt.figure(figsize=(largura, altura))

plt.plot(Alpha,Rsqu_teste, label='Dados de validação')
plt.plot(Alpha,Rsqu_treino, 'r', label='Dados de treino')
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.legend()

# %% [markdown]
# A linha azul representa o R^2 dos dados de validação e a linha vermelha representa o R^2 dos dados de treinamento. O eixo x representa os diferentes valores de Alpha.

# %% [markdown]
# Aqui o modelo é construído e testado com os mesmos dados, portanto os dados de treinamento e teste são os mesmos.
#
# A linha vermelha na figura representa o R^2 dos dados de treinamento. À medida que alfa aumenta, R^2 diminui. Portanto, à medida que o alfa aumenta, o modelo tem pior desempenho nos dados de treinamento
#
# A linha azul representa o R^2 nos dados de validação. À medida que o valor de alfa aumenta, o R^2 aumenta e converge em um ponto.

# %%
RigeModel = Ridge(alpha=10) 
RigeModel.fit(x_treino_pr, y_treino)
RigeModel.score(x_teste_pr, y_teste)
# Out:
# /home/leonardo/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.17189e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# 0.5802633843261922

# %% [markdown]
# ## Grid Search

# %% [markdown]
# O termo alfa é um hiperparâmetro. Sklearn possui a classe GridSearchCV para simplificar o processo de localização do melhor hiperparâmetro.

# %%
parametros1= [{'alpha': [0.001,0.1,1, 10, 100, 1000, 10000, 100000, 100000]}]
parametros1
# Out:
# [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

# %%
RR=Ridge()
RR
# Out:
# Ridge()

# %% [markdown]
# Cria um objeto de pesquisa GridSearch:

# %%
Grid1 = GridSearchCV(RR, parametros1,cv=4)

# %%
Grid1.fit(x_data[['potencia', 'peso-do-meio-fio', 'tamanho-do-motor', 'consumo-na-estrada']], y_data)
# Out:
# GridSearchCV(cv=4, estimator=Ridge(),
#              param_grid=[{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000,
#                                     100000]}])

# %%
BestRR=Grid1.best_estimator_
BestRR
# Out:
# Ridge(alpha=10000)

# %%
BestRR.score(x_teste[['potencia', 'peso-do-meio-fio', 'tamanho-do-motor', 'consumo-na-estrada']], y_teste)
# Out:
# 0.841164983103615

# %%
parametros2 = [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

Grid2 = GridSearchCV(Ridge(), parametros2, cv=4)
Grid2.fit(x_data[['potencia', 'peso-do-meio-fio', 'tamanho-do-motor', 'consumo-na-estrada']], y_data)
best_alpha = Grid2.best_params_['alpha']
best_ridge_model = Ridge(alpha=best_alpha)
best_ridge_model.fit(x_data[['potencia', 'peso-do-meio-fio', 'tamanho-do-motor', 'consumo-na-estrada']], y_data)
# Out:
# Ridge(alpha=10000)

# %% [markdown]
# ## Autor: Leonardo Mattana
